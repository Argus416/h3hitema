# %% [markdown]
# # 1. Visualisation d’un nuage de points et exploration des variables

# %% [markdown]
# Pour cette partie, nous allons utiliser le dataset suivante : house_pricing.csv que vous pouvez trouver dans le dossier Data Sources. Nous allons tenter de comprendre un peu mieux ce dataset par la visualisation

# %% [markdown]
# ## 1.1 Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot

# %% [markdown]
# ## 1.2 Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc...) et leur type (float, int, str etc...)

# %%
csvFilePath = "./Data/house_pricing.csv"

df = pd.read_csv(csvFilePath)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## 1.3 En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices

# %%
sns.set_theme()

sns.relplot(
    data=df,
    x="LotArea", y="SalePrice", marker="x", 
)

# %% [markdown]
# ## 1.4 Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000$

# %%
df = df[ (df.LotArea < 20000) & (df.SalePrice < 500000)]; df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## 1.5 En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea

# %%
sns.relplot(
    data=df,
    x="LotArea", y="SalePrice"
)

# %% [markdown]
# ## 1.6 De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré

# %%
df = df[(df.LotFrontage < 200) & (df.LotArea < 100000)]

# %%
sns.relplot(
    data=df,
    x="LotArea", y="SalePrice", s = 20, height= 10
)

# %% [markdown]
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# # 2 Visualisation de relations continues

# %% [markdown]
# Pour cette partie, nous utiliserons le dataset suivant : sales_predictions.csv que vous pouvez
# trouver dans le dossier Data Sources.

# %% [markdown]
# ## 2.1 Importez les librairies qu’il vous faut

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot

# %% [markdown]
# ## 2.2 En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution des prix par rapport au temps. Que pouvez vous voir ?

# %%
csvFilePath = "./Data/sales_predictions.csv"

csvContent = pd.read_csv(csvFilePath)
df = pd.DataFrame(csvContent, columns=['item_price', "date"]); df


sns.relplot(
    data=df,
    x="date", y="item_price"
)

# %% [markdown]
# ## 2.3 Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

# %%
df = df.sample(50, replace=True);


sns.relplot(
    data=df,
    x="date", y="item_price"
)

# %% [markdown]
# ## 2.4 Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
df.plot(figsize=(20,6));

# %% [markdown]
# ## 2.5 En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime

# %%
#pd.Series(['foo', 'fuz', np.nan]).str.replace('f.', 'ba', regex=True)
df.date = pd.to_datetime(df.date, infer_datetime_format=True, errors='ignore')
# Out:
# /var/folders/2j/4hpnz4nj4td3m67qrbtdhc000000gn/T/ipykernel_30370/218264187.py:2: UserWarning: Parsing '14.03.2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.date = pd.to_datetime(df.date, infer_datetime_format=True, errors='ignore')
# /var/folders/2j/4hpnz4nj4td3m67qrbtdhc000000gn/T/ipykernel_30370/218264187.py:2: UserWarning: Parsing '30.09.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.date = pd.to_datetime(df.date, infer_datetime_format=True, errors='ignore')
# /var/folders/2j/4hpnz4nj4td3m67qrbtdhc000000gn/T/ipykernel_30370/218264187.py:2: UserWarning: Parsing '24.06.2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.date = pd.to_datetime(df.date, infer_datetime_format=True, errors='ignore')
# ...

# %% [markdown]
# ## 2.6 Retentez une dernière fois votre visualisation

# %%
sns.lineplot(
    data=df,
    x="date", y="item_price"
)
# Out:
# <AxesSubplot: xlabel='date', ylabel='item_price'>

# %% [markdown]
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# # 3 Visualisation de variables catégoriques

# %% [markdown]
# Pour cette partie, nous utiliserons le dataset suivant : ibm_hr_attrition.csv que vous pouvez trouver dans le dossier Data Sources

# %% [markdown]
# ## 3.1 Importez les librairies qu’il vous faut

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot


csvFilePath = "./Data/IBM_HR_ATTRITION.csv"

df = pd.read_csv(csvFilePath)

#df
df.YearsAtCompany
# Out:
# 0        6
# 1       10
# 2        0
# 3        8
# 4        2
#         ..
# 1465     5
# 1466     7
# 1467     6
# 1468     9
# 1469     4
# Name: YearsAtCompany, Length: 1470, dtype: int64

# %% [markdown]
# ## 3.2 En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction

# %%
df.dtypes

#YearsAtCompany
#JobSatisfaction

sns.catplot(x="JobSatisfaction", y="YearsAtCompany", data=df)

# %% [markdown]
# ## 3.3 Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
sns.boxplot(x="JobSatisfaction", y="YearsAtCompany", data=df)
# Out:
# <AxesSubplot: xlabel='JobSatisfaction', ylabel='YearsAtCompany'>

# %% [markdown]
# ## 3.4 Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?

# %%
#OUI

# %% [markdown]
# ## 3.5 Isolez les observations présentant des valeurs aberrantes pour la variable JobSatisfaction en fonction de la variable indiquant si ils ont quitté l’entreprise ou nom

# %%
filtererVarAbarr = df[df.YearsAtCompany < 25];
sns.boxplot(x="JobSatisfaction", y="YearsAtCompany", data=filtererVarAbarr)
# Out:
# <AxesSubplot: xlabel='JobSatisfaction', ylabel='YearsAtCompany'>

# %% [markdown]
# ## 3.6 Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des statistiques descriptives du dataset.

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## 3.7 Comparez les individus présentant des valeurs aberrantes pour la variable JobSatisfaction avec les statistiques descriptives du dataset, remarquez vous des différences notoires ?

# %%
varAbarr = df[df.YearsAtCompany > 25];
sns.boxplot(x="JobSatisfaction", y="YearsAtCompany", data=varAbarr)
# Out:
# <AxesSubplot: xlabel='JobSatisfaction', ylabel='YearsAtCompany'>

# %% [markdown]
# ## 3.8 Faites de même avec le TotalWorkingYears. Que pouvez vous conclure ?

# %%
varAbarr.TotalWorkingYears.sum()
# Out:
# 815

# %%
filtererVarAbarr.TotalWorkingYears.sum()
# Out:
# 15659

# %% [markdown]
# ## 3.9 Remplacer les valeurs de la colonne Attrition par 1 pour Yes et 0 pour No

# %%
df.Attrition = df.Attrition.str.replace('Yes', '1', regex=True)
df.Attrition = df.Attrition.str.replace('No', '0', regex=True)

df.Attrition
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: object

# %% [markdown]
# ## 3.10 En utilisant un Histogramme, regardez la répartition du taux de départ par EducationField

# %%
sns.histplot(data=df, x="EducationField", y="YearsAtCompany", discrete=False)
# Out:
# <AxesSubplot: xlabel='EducationField', ylabel='YearsAtCompany'>

# %% [markdown]
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# # 4 Visualisation d’une distribution

# %% [markdown]
# Continuons sur ibm_hr_attritition.csv

# %% [markdown]
# ## 4.1 Importez les librairies qu’il vous faut

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot


csvFilePath = "./Data/IBM_HR_ATTRITION.csv"

df = pd.read_csv(csvFilePath)

# %% [markdown]
# ## 4.2 En utilisant distplot(), construisez un graphique qui permette de voir la distribution des revenues par mois chez IBM (MonthlyIncome)

# %%
sns.histplot(data=df, x="MonthlyIncome")
# Out:
# <AxesSubplot: xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# ## 4.3 On peut voir que les très haut salaires biaisent notre distribution, essayons de voir la distribution des salaires entre 0 et 5000 $ / mois

# %%
filterSalaire = df[(df.MonthlyIncome > 0) & (df.MonthlyIncome < 5000)]
sns.histplot(data=filterSalaire, x="MonthlyIncome")
# Out:
# <AxesSubplot: xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# # 5 Visualisation d’une relation linéaire

# %% [markdown]
# Toujours sur ibm_hr_attrition.csv

# %% [markdown]
# ## 5.1 Importez les librairies qu’il vous faut

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot


csvFilePath = "./Data/IBM_HR_ATTRITION.csv"

df = pd.read_csv(csvFilePath)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.DistanceFromHome
# Out:
# 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64

# %% [markdown]
# ## 5.2 On voudrait connaître la probabilité de partir de la l’entreprise par rapport à la distance par rapport à la maison. Utilisez lmplot() pour visualiser cela. Que pouvez vous conclure ?

# %%
sns.lmplot(data=df, x="YearsAtCompany", y="DistanceFromHome", height=8)

# Que les gens quittes la boîte à cause d'une raison d'autre que la distance

# %% [markdown]
# ## 5.3 Tentez le cette fois avec le nombre d’années passées avec le Manager (YearsWithCurrManager), que pouvez vous conclure ?

# %%
sns.lmplot(data=df, x="YearsAtCompany", y="YearsWithCurrManager", height=8)

# %% [markdown]
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# # 6 Visualisation d’une heatmap

# %% [markdown]
# Revenons sur <b>house_pricing.csv</b>, et tentons de faire un peu de ce qu’on appelle
# communément : <b>feature_engineering<b>

# %% [markdown]
# ## 6.1 Importez les librairies habituelles

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as mpot


csvFilePath = "./Data/house_pricing.csv"

df = pd.read_csv(csvFilePath)

# %% [markdown]
# ## 6.2 Découpez votre dataset pour ne garder que les 15 dernieres colonnes

# %%
df = df.iloc[:,-16:-1]

df
# Out:
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0             Y           0           61              0          0
# 1             Y         298            0              0          0
# 2             Y           0           42              0          0
# 3             Y           0           35            272          0
# 4             Y         192           84              0          0
# ...         ...         ...          ...            ...        ...
# 1455          Y           0           40              0          0
# 1456          Y         349            0              0          0
# 1457          Y           0           60              0          0
# 1458          Y         366            0            112          0
# 1459          Y         736           68              0          0
#
#       ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  \
# 0               0         0    NaN    NaN         NaN        0       2
# ...

# %% [markdown]
# ## 6.3 Créez une matrice de corrélation avec toutes les variables du Dataset

# %%
matriceDeCorrelation = df.corr(method='pearson')

# %% [markdown]
# ## 6.4 Créez une heatmap avec les différentes valeur de corrélation

# %%
sns.heatmap(data=matriceDeCorrelation, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 6.5 Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?

# %%
# YrSold
# MoSold
# MiscSold
